# %% [markdown]
# Generated by ChatGPT

# %%
from transformers import Trainer, TrainingArguments
from datasets import load_dataset

# Load a dataset (example dataset, replace with your own)
dataset = load_dataset("wikitext", "wikitext-2-raw-v1", split="train")

# Preprocess dataset
def preprocess_function(examples):
    return tokenizers["aubmindlab/bert-base-arabertv02"](examples["text"], truncation=True, padding=True)

tokenized_dataset = dataset.map(preprocess_function, batched=True)

# Define training arguments
training_args = TrainingArguments(
    output_dir="./results",
    overwrite_output_dir=True,
    num_train_epochs=3,
    per_device_train_batch_size=4,
    save_steps=10_000,
    save_total_limit=2,
)

# Initialize the Trainer
trainer = Trainer(
    model=models["aubmindlab/bert-base-arabertv02"],
    args=training_args,
    train_dataset=tokenized_dataset,
)

# Train the model
trainer.train()

# Save the model
trainer.save_model("./fine-tuned-arabert")
